# %% [markdown]
# # install dependency

# %%
# !pip install demucs
# !pip install soundfile
# !pip install librosa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting demucs
#   Downloading demucs-4.0.0.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dora-search (from demucs)
#   Downloading dora_search-0.1.11.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.0/87.0 kB 11.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting diffq>=0.2.1 (from demucs)
#   Downloading diffq-0.2.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (418 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.8/418.8 kB 42.2 MB/s eta 0:00:00
# Collecting einops (from demucs)
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.9 MB/s eta 0:00:00
# Collecting julius>=0.2.3 (from demucs)
#   Downloading julius-0.2.7.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting lameenc>=1.2 (from demucs)
#   Downloading lameenc-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.5/189.5 kB 19.9 MB/s eta 0:00:00
# Collecting openunmix (from demucs)
#   Downloading openunmix-1.2.1-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from demucs) (6.0)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from demucs) (2.0.0+cu118)
# Requirement already satisfied: torchaudio>=0.8 in /usr/local/lib/python3.10/dist-packages (from demucs) (2.0.1+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from demucs) (4.65.0)
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from diffq>=0.2.1->demucs) (0.29.34)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffq>=0.2.1->demucs) (1.22.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->demucs) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->demucs) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->demucs) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->demucs) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->demucs) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->demucs) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->demucs) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->demucs) (16.0.3)
# Collecting omegaconf (from dora-search->demucs)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 11.3 MB/s eta 0:00:00
# Collecting retrying (from dora-search->demucs)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting submitit (from dora-search->demucs)
#   Downloading submitit-1.4.5-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 10.0 MB/s eta 0:00:00
# Collecting treetable (from dora-search->demucs)
#   Downloading treetable-0.2.5.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.1->demucs) (2.1.2)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf->dora-search->demucs)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 15.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from retrying->dora-search->demucs) (1.16.0)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from submitit->dora-search->demucs) (2.2.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.1->demucs) (1.3.0)
# Building wheels for collected packages: demucs, julius, dora-search, antlr4-python3-runtime, treetable
#   Building wheel for demucs (setup.py) ... done
#   Created wheel for demucs: filename=demucs-4.0.0-py3-none-any.whl size=76505 sha256=c691b2be54a74757f73f82446495635a1c518df90e469c7b624709270cfd1dda
#   Stored in directory: /root/.cache/pip/wheels/64/fc/2e/a8e874bba1518a336f21a94085013fba17cb86658ce18ec1c7
#   Building wheel for julius (setup.py) ... done
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21878 sha256=b56ee2c6fc9a831ec84b3b1c39de6b9c9607e6d3c24455e77b1ea2d5dd45f411
#   Stored in directory: /root/.cache/pip/wheels/b9/b2/05/f883527ffcb7f2ead5438a2c23439aa0c881eaa9a4c80256f4
#   Building wheel for dora-search (pyproject.toml) ... done
#   Created wheel for dora-search: filename=dora_search-0.1.11-py3-none-any.whl size=74991 sha256=4a6f5a480cf4e2dab21a3e70b63bec2311e1863678a256c93345eb8f40587a65
#   Stored in directory: /root/.cache/pip/wheels/a3/e6/9c/47aaef1ea88bd63244dea69547ceff3e6eedf03a122d39d727
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=49576f95190a56252863de96f44daf1316c384aa5b21bee08b177b6c6925707c
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for treetable (setup.py) ... done
#   Created wheel for treetable: filename=treetable-0.2.5-py3-none-any.whl size=7332 sha256=b8ae08ffb3fd5f6e1d1df0e7b451b759e0b5d797326bdfea26e2891c93b75521
#   Stored in directory: /root/.cache/pip/wheels/72/55/0e/91c3655bdb162446f8a7cd477579397544454a63ae7c599c0c
# Successfully built demucs julius dora-search antlr4-python3-runtime treetable
# Installing collected packages: lameenc, antlr4-python3-runtime, treetable, submitit, retrying, omegaconf, einops, openunmix, julius, dora-search, diffq, demucs
# Successfully installed antlr4-python3-runtime-4.9.3 demucs-4.0.0 diffq-0.2.4 dora-search-0.1.11 einops-0.6.1 julius-0.2.7 lameenc-1.4.2 omegaconf-2.3.0 openunmix-1.2.1 retrying-1.3.4 submitit-1.4.5 treetable-0.2.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (0.12.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile) (2.21)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.0.post2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.0)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.22.4)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.56.4)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch<1.7,>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.6.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3.5)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.5.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.2)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.0.5)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (67.7.2)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pooch<1.7,>=1.0->librosa) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pooch<1.7,>=1.0->librosa) (23.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch<1.7,>=1.0->librosa) (2.27.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (3.4)

# %% [markdown]
# #Imports

# %%
import os
import soundfile
import librosa
import glob
import tqdm

# %% [markdown]
# # setting paths

# %%
songs_path = "/content/drive/MyDrive/songs"
vocals_path = "/content/drive/MyDrive/vocals"
# Create directories if they do not exist
if not os.path.exists(songs_path):
    os.makedirs(songs_path)

if not os.path.exists(vocals_path):
    os.makedirs(vocals_path)

# %% [markdown]
# # extract vocal

# %%
ctr = 0
model = "mdx_extra_q"
for audio_file in tqdm.tqdm(os.listdir(songs_path)):
    # !demucs -n mdx_extra_q --two-stems=vocals "{os.path.join(songs_path, audio_file)}" -o {vocals_path}
    vocal_name=f"vocal_{ctr}.wav"
    song_name = os.path.splitext(audio_file)[0]

    # !mv "{os.path.join(vocals_path, model, song_name, 'vocals.wav')}" "{os.path.join(vocals_path, vocal_name)}"
    # !rm -r "{os.path.join(vocals_path, model, song_name)}/"

    ctr += 1

# %% [markdown]
# # remove silence

# %% [markdown]
# # class

# %%
# code from : https://github.com/openvpi/audio-slicer

import numpy as np

def get_rms(
    y,
    *,
    frame_length=2048,
    hop_length=512,
    pad_mode="constant",
):
    padding = (int(frame_length // 2), int(frame_length // 2))
    y = np.pad(y, padding, mode=pad_mode)

    axis = -1
    # put our new within-frame axis at the end for now
    out_strides = y.strides + tuple([y.strides[axis]])
    # Reduce the shape on the framing axis
    x_shape_trimmed = list(y.shape)
    x_shape_trimmed[axis] -= frame_length - 1
    out_shape = tuple(x_shape_trimmed) + tuple([frame_length])
    xw = np.lib.stride_tricks.as_strided(
        y, shape=out_shape, strides=out_strides
    )
    if axis < 0:
        target_axis = axis - 1
    else:
        target_axis = axis + 1
    xw = np.moveaxis(xw, -1, target_axis)
    # Downsample along the target axis
    slices = [slice(None)] * xw.ndim
    slices[axis] = slice(0, None, hop_length)
    x = xw[tuple(slices)]

    # Calculate power
    power = np.mean(np.abs(x) ** 2, axis=-2, keepdims=True)

    return np.sqrt(power)


class Slicer:
    def __init__(self,
                 sr: int,
                 threshold: float = -40.,
                 min_length: int = 5000,
                 min_interval: int = 300,
                 hop_size: int = 20,
                 max_sil_kept: int = 5000):
        if not min_length >= min_interval >= hop_size:
            raise ValueError('The following condition must be satisfied: min_length >= min_interval >= hop_size')
        if not max_sil_kept >= hop_size:
            raise ValueError('The following condition must be satisfied: max_sil_kept >= hop_size')
        min_interval = sr * min_interval / 1000
        self.threshold = 10 ** (threshold / 20.)
        self.hop_size = round(sr * hop_size / 1000)
        self.win_size = min(round(min_interval), 4 * self.hop_size)
        self.min_length = round(sr * min_length / 1000 / self.hop_size)
        self.min_interval = round(min_interval / self.hop_size)
        self.max_sil_kept = round(sr * max_sil_kept / 1000 / self.hop_size)

    def _apply_slice(self, waveform, begin, end):
        if len(waveform.shape) > 1:
            return waveform[:, begin * self.hop_size: min(waveform.shape[1], end * self.hop_size)]
        else:
            return waveform[begin * self.hop_size: min(waveform.shape[0], end * self.hop_size)]

    def slice(self, waveform):
        if len(waveform.shape) > 1:
            samples = waveform.mean(axis=0)
        else:
            samples = waveform
        if samples.shape[0] <= self.min_length:
            return [waveform]
        # if samples.shape[0]//self.hop_size <= self.min_length:
        #     return [waveform]

        rms_list = get_rms(y=samples, frame_length=self.win_size, hop_length=self.hop_size).squeeze(0)
        sil_tags = []
        silence_start = None
        clip_start = 0
        for i, rms in enumerate(rms_list):
            # Keep looping while frame is silent.
            if rms < self.threshold:
                # Record start of silent frames.
                if silence_start is None:
                    silence_start = i
                continue
            # Keep looping while frame is not silent and silence start has not been recorded.
            if silence_start is None:
                continue
            # Clear recorded silence start if interval is not enough or clip is too short
            is_leading_silence = silence_start == 0 and i > self.max_sil_kept
            need_slice_middle = i - silence_start >= self.min_interval and i - clip_start >= self.min_length
            if not is_leading_silence and not need_slice_middle:
                silence_start = None
                continue
            # Need slicing. Record the range of silent frames to be removed.
            if i - silence_start <= self.max_sil_kept:
                pos = rms_list[silence_start: i + 1].argmin() + silence_start
                if silence_start == 0:
                    sil_tags.append((0, pos))
                else:
                    sil_tags.append((pos, pos))
                clip_start = pos
            elif i - silence_start <= self.max_sil_kept * 2:
                pos = rms_list[i - self.max_sil_kept: silence_start + self.max_sil_kept + 1].argmin()
                pos += i - self.max_sil_kept
                pos_l = rms_list[silence_start: silence_start + self.max_sil_kept + 1].argmin() + silence_start
                pos_r = rms_list[i - self.max_sil_kept: i + 1].argmin() + i - self.max_sil_kept
                if silence_start == 0:
                    sil_tags.append((0, pos_r))
                    clip_start = pos_r
                else:
                    sil_tags.append((min(pos_l, pos), max(pos_r, pos)))
                    clip_start = max(pos_r, pos)
            else:
                pos_l = rms_list[silence_start: silence_start + self.max_sil_kept + 1].argmin() + silence_start
                pos_r = rms_list[i - self.max_sil_kept: i + 1].argmin() + i - self.max_sil_kept
                if silence_start == 0:
                    sil_tags.append((0, pos_r))
                else:
                    sil_tags.append((pos_l, pos_r))
                clip_start = pos_r
            silence_start = None
        # Deal with trailing silence.
        total_frames = rms_list.shape[0]
        if silence_start is not None and total_frames - silence_start >= self.min_interval:
            silence_end = min(total_frames, silence_start + self.max_sil_kept)
            pos = rms_list[silence_start: silence_end + 1].argmin() + silence_start
            sil_tags.append((pos, total_frames + 1))
        # Apply and return slices.
        if len(sil_tags) == 0:
            return [waveform]
        else:
            chunks = []
            if sil_tags[0][0] > 0:
                chunks.append(self._apply_slice(waveform, 0, sil_tags[0][0]))
            for i in range(len(sil_tags) - 1):
                chunks.append(self._apply_slice(waveform, sil_tags[i][1], sil_tags[i + 1][0]))
            if sil_tags[-1][1] < total_frames:
                chunks.append(self._apply_slice(waveform, sil_tags[-1][1], total_frames))
            return chunks

# %% [markdown]
# # code for splitting at silence

# %%
########       remove the silence from audio and split at that silence

non_silence_audio = "/content/drive/MyDrive/non_silenced/"
if not os.path.exists(non_silence_audio):
    os.makedirs(non_silence_audio)

for audio_path in os.listdir(vocals_path):
    print(audio_path)
    audio_path = os.path.join(vocals_path, audio_path)
    if len(os.path.basename(audio_path).split(".")) == 1:
      continue
    audio_name = os.path.basename(audio_path).split(".")[0]
    audio, sr = librosa.load(audio_path, sr=None, mono=False)
    slicer = Slicer(
        sr=sr,
        threshold=-25,
        min_length=7000,
        min_interval=600,
        hop_size=15,
        max_sil_kept=700
    )
    chunks = slicer.slice(audio)
    for i, chunk in enumerate(chunks):
        if len(chunk.shape) > 1:
            chunk = chunk.T  # Swap axes if the audio is stereo.

        print("\twrote: "+os.path.join(non_silence_audio,f'{audio_name}_{i}.wav'))
        soundfile.write(os.path.join(non_silence_audio,f'{audio_name}_{i}.wav'), chunk, sr)  # Save sliced audio files with soundfile.
# Out:
# live.mp3
# 	wrote: /content/drive/MyDrive/non_silenced/live_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_7.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_8.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_9.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_10.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_11.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_12.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_13.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_14.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_15.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_16.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_17.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_18.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_19.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_20.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_21.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_22.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_23.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_24.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_25.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_26.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_27.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_28.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_29.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_30.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_31.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_32.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_33.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_34.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_35.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_36.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_37.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_38.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_39.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_40.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_41.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_42.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_43.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_44.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_45.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_46.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_47.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_48.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_49.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_50.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_51.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_52.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_53.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_54.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_55.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_56.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_57.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_58.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_59.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_60.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_61.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_62.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_63.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_64.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_65.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_66.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_67.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_68.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_69.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_70.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_71.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_72.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_73.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_74.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_75.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_76.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_77.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_78.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_79.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_80.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_81.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_82.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_83.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_84.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_85.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_86.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_87.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_88.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_89.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_90.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_91.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_92.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_93.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_94.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_95.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_96.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_97.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_98.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_99.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_100.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_101.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_102.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_103.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_104.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_105.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_106.wav
# 	wrote: /content/drive/MyDrive/non_silenced/live_107.wav
# mdx_extra_q
# vocal_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_0_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_0_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_0_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_0_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_0_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_0_5.wav
# vocal_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_1_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_1_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_1_2.wav
# vocal_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_2_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_2_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_2_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_2_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_2_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_2_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_2_6.wav
# vocal_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_3_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_3_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_3_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_3_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_3_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_3_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_3_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_3_7.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_3_8.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_3_9.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_3_10.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_3_11.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_3_12.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_3_13.wav
# vocal_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_4_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_4_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_4_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_4_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_4_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_4_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_4_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_4_7.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_4_8.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_4_9.wav
# vocal_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_5_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_5_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_5_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_5_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_5_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_5_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_5_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_5_7.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_5_8.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_5_9.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_5_10.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_5_11.wav
# vocal_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_6_0.wav
# vocal_7.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_7_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_7_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_7_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_7_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_7_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_7_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_7_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_7_7.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_7_8.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_7_9.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_7_10.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_7_11.wav
# vocal_8.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_8_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_8_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_8_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_8_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_8_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_8_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_8_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_8_7.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_8_8.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_8_9.wav
# vocal_9.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_9_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_9_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_9_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_9_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_9_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_9_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_9_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_9_7.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_9_8.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_9_9.wav
# vocal_10.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_10_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_10_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_10_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_10_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_10_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_10_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_10_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_10_7.wav
# vocal_11.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_11_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_11_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_11_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_11_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_11_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_11_5.wav
# vocal_12.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_12_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_12_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_12_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_12_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_12_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_12_5.wav
# vocal_13.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_13_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_13_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_13_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_13_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_13_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_13_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_13_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_13_7.wav
# vocal_14.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_14_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_14_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_14_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_14_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_14_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_14_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_14_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_14_7.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_14_8.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_14_9.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_14_10.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_14_11.wav
# vocal_15.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_15_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_15_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_15_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_15_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_15_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_15_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_15_6.wav
# vocal_16.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_16_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_16_1.wav
# vocal_17.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_17_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_17_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_17_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_17_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_17_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_17_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_17_6.wav
# vocal_18.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_18_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_18_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_18_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_18_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_18_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_18_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_18_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_18_7.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_18_8.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_18_9.wav
# vocal_19.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_19_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_19_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_19_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_19_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_19_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_19_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_19_6.wav
# vocal_20.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_7.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_8.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_9.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_10.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_11.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_12.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_13.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_14.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_15.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_16.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_17.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_20_18.wav
# vocal_21.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_21_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_21_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_21_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_21_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_21_4.wav
# vocal_22.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_7.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_8.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_9.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_10.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_11.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_12.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_13.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_14.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_15.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_16.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_17.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_18.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_19.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_20.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_22_21.wav
# vocal_23.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_23_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_23_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_23_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_23_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_23_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_23_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_23_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_23_7.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_23_8.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_23_9.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_23_10.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_23_11.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_23_12.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_23_13.wav
# vocal_24.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_24_0.wav
# vocal_25.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_25_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_25_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_25_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_25_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_25_4.wav
# vocal_26.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_26_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_26_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_26_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_26_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_26_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_26_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_26_6.wav
# vocal_27.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_27_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_27_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_27_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_27_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_27_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_27_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_27_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_27_7.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_27_8.wav
# vocal_28.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_28_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_28_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_28_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_28_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_28_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_28_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_28_6.wav
# vocal_29.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_29_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_29_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_29_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_29_3.wav
# vocal_30.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_30_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_30_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_30_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_30_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_30_4.wav
# vocal_31.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_31_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_31_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_31_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_31_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_31_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_31_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_31_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_31_7.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_31_8.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_31_9.wav
# vocal_32.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_32_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_32_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_32_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_32_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_32_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_32_5.wav
# vocal_33.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_33_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_33_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_33_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_33_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_33_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_33_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_33_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_33_7.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_33_8.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_33_9.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_33_10.wav
# vocal_34.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_34_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_34_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_34_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_34_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_34_4.wav
# vocal_35.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_35_0.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_35_1.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_35_2.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_35_3.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_35_4.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_35_5.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_35_6.wav
# 	wrote: /content/drive/MyDrive/non_silenced/vocal_35_7.wav

# %% [markdown]
# # split to 6 seconds clip

# %%
#####       split audios in clips of 5 seconds for training
from tqdm import tqdm

# set parameters
min_length = 6     # minimum length of each segment in seconds

sliced_dir = "/content/drive/MyDrive/sliced/"
# create output directory if it doesn't exist
if not os.path.exists(sliced_dir):
    os.makedirs(sliced_dir)

print(f"slicing audios to clips of {min_length}seconds")
cnt = 0
# loop through all .mp3 files in original_audio directory
for file in tqdm(os.listdir(non_silence_audio)):
    if file.endswith('.wav'):
        # load audio file
        audio_name = file.split('.')[0]
        audio_path = os.path.join(non_silence_audio, file)
        audio, sr = librosa.load(audio_path)

        min_samples = int(min_length * sr)

        # Split the audio into segments
        segments = []
        segment_start = 0
        while segment_start + min_samples < len(audio):
            segment_end = segment_start + min_samples
            segments.append(audio[segment_start:segment_end])
            segment_start = segment_end

        # Write each segment to a separate file
        for i, segment in enumerate(segments):
            segment_path = os.path.join(sliced_dir,f'segments_{audio_name}_{cnt}.wav')
            cnt += 1
            soundfile.write(segment_path, segment, sr)
# Out:
# slicing audios to clips of 6seconds
# 100%|██████████| 398/398 [00:36<00:00, 10.85it/s]
